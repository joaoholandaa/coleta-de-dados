# %%
import requests
import pandas as pd
import datetime
import json
import time

# %%
def get_response(**kwargs):
    url = "https://www.tabnews.com.br/api/v1/contents/"
    resp = requests.get(url, params=kwargs)
    return resp

# %%
def save_data(data, option='json'):

    now = datetime.datetime.now().strftime("%Y%m%d_%H%M%S.%f")

    if option == 'json':
        with open(f"data/contents/json/{now}.json", 'w') as open_file:
            json.dump(data, open_file)
    
    elif option == 'dataframe':
        df = pd.DataFrame(data)
        df.to_parquet(f"data/contents/parquet/{now}.parquet", index=False)

# %%
page = 1
date_stop = pd.to_datetime('2024-09-15').date()
while True:
    print(page)
    resp = get_response(page=page, per_page=100, strategy="new")
    if resp.status_code == 200:
        data = resp.json()
        save_data(data)
        date = pd.to_datetime(data[-1]["updated_at"]).date()
        if len(data) < 100 or date < date_stop:
            break
        page += 1
        time.sleep(2)
    else:
        print(resp.status_code)
        print(resp.json())
        time.sleep(60*15)
# Out:
# 1

# %%
df = pd.DataFrame(data)
df
# Out:
#                                       id  \
# 0   f40307ad-7ba0-42a6-89d9-affbbc529ca0
# 1   8f977afb-1b5e-400f-a804-92c791440476
# 2   72ed3e1f-32c0-4e0a-b545-7ec79107eb37
# 3   c6b348bf-03fb-461a-89c7-8c88ec779a30
# 4   b23e7979-0029-4f46-8a5b-5a321c8d3050
# ..                                   ...
# 95  9224debf-fc20-4f72-a958-8ecb6564f9a6
# 96  82bd95ca-85cc-49f0-a2c5-08a1d1b0a9f3
# 97  17c426ff-76d1-4d8a-b023-81c023ca05fa
# 98  e7c5e661-0fa6-4e34-9f93-b7b5347005e2
# 99  b8749f06-59cb-4215-a970-f253726c621d
#
#                                 owner_id parent_id  \
# 0   9ced61b1-a8a7-431e-874d-fe043e8dd3aa      None
# 1   256d0e13-b15c-4ae3-94b8-d75a395b12fb      None
# 2   f8d84451-393f-4eff-bee7-6af4a6f568af      None
# 3   bcb4880d-2814-47cf-a12b-3db6397efde2      None
# 4   256d0e13-b15c-4ae3-94b8-d75a395b12fb      None
# ..                                   ...       ...
# 95  3770c063-0231-45b2-9d69-23359fe3a1a4      None
# 96  9b458c0b-0c21-433f-a8f0-2efd3dd884b1      None
# 97  797a6987-228c-42cc-ade5-1d2b5b9a4dd0      None
# 98  a3e66be5-62b4-40cd-892d-0267188ab05d      None
# 99  add30b20-4fe2-4b46-9148-e9e956c143f5      None
#
#                                                  slug  \
# 0   por-causa-do-banimento-twitter-x-fiz-minha-pro...
# 1   como-gerei-mais-de-200-thumbnails-em-menos-de-...
# 2   desenvolvi-um-sistema-que-valida-a-ideia-do-cl...
# 3   primeira-contribuicao-no-repositorio-algorithm...
# 4   lista-de-desafios-tecnicos-qa-mobile-backend-e...
# ..                                                ...
# 95  pitch-novidades-jogos-em-promocao-mais-de-4-mi...
# 99  2024-09-13T14:56:14.173Z       None        Wellington79         1
#
#     tabcoins_credit  tabcoins_debit  children_deep_count
# 0                 0               0                    0
# 1                 0               0                    0
# 2                 0               0                    0
# 3                 0               0                    0
# 4                 0               0                    0
# ..              ...             ...                  ...
# 95                3               0                    5
# 96                0               0                    0
# 97                2              -5                    4
# 98                3               0                    0
# 99                0               0                    0
#
# [100 rows x 17 columns]

# %%
df.to_parquet("data/contents/parquet/dados_tn.parquet", index=False)

# %%
df_new = pd.read_parquet("data/contents/parquet/dados_tn.parquet")
df_new
# Out:
#                                       id  \
# 0   f40307ad-7ba0-42a6-89d9-affbbc529ca0
# 1   8f977afb-1b5e-400f-a804-92c791440476
# 2   72ed3e1f-32c0-4e0a-b545-7ec79107eb37
# 3   c6b348bf-03fb-461a-89c7-8c88ec779a30
# 4   b23e7979-0029-4f46-8a5b-5a321c8d3050
# ..                                   ...
# 95  9224debf-fc20-4f72-a958-8ecb6564f9a6
# 96  82bd95ca-85cc-49f0-a2c5-08a1d1b0a9f3
# 97  17c426ff-76d1-4d8a-b023-81c023ca05fa
# 98  e7c5e661-0fa6-4e34-9f93-b7b5347005e2
# 99  b8749f06-59cb-4215-a970-f253726c621d
#
#                                 owner_id parent_id  \
# 0   9ced61b1-a8a7-431e-874d-fe043e8dd3aa      None
# 1   256d0e13-b15c-4ae3-94b8-d75a395b12fb      None
# 2   f8d84451-393f-4eff-bee7-6af4a6f568af      None
# 3   bcb4880d-2814-47cf-a12b-3db6397efde2      None
# 4   256d0e13-b15c-4ae3-94b8-d75a395b12fb      None
# ..                                   ...       ...
# 95  3770c063-0231-45b2-9d69-23359fe3a1a4      None
# 96  9b458c0b-0c21-433f-a8f0-2efd3dd884b1      None
# 97  797a6987-228c-42cc-ade5-1d2b5b9a4dd0      None
# 98  a3e66be5-62b4-40cd-892d-0267188ab05d      None
# 99  add30b20-4fe2-4b46-9148-e9e956c143f5      None
#
#                                                  slug  \
# 0   por-causa-do-banimento-twitter-x-fiz-minha-pro...
# 1   como-gerei-mais-de-200-thumbnails-em-menos-de-...
# 2   desenvolvi-um-sistema-que-valida-a-ideia-do-cl...
# 3   primeira-contribuicao-no-repositorio-algorithm...
# 4   lista-de-desafios-tecnicos-qa-mobile-backend-e...
# ..                                                ...
# 95  pitch-novidades-jogos-em-promocao-mais-de-4-mi...
# 96  flappy-bird-iconico-jogo-mobile-de-2014-sera-r...
# 97                               nao-consigo-comentar
# 98  nodejs-validation-br-atualizada-com-suporte-a-...
# 99  tecnologia-raio-x-caseiro-gerador-de-alta-tens...
#
#                                                 title     status     type  \
# 0   Por causa do banimento Twitter (X) fiz minha p...  published  content
# 1   Como gerei mais de 200 thumbnails em menos de ...  published  content
# 2   Desenvolvi um sistema que Valida  a ideia do c...  published  content
# 3   🚀 Primeira Contribuição no Repositório "algori...  published  content
# 4   Lista de desafios técnicos [QA, Mobile, Backen...  published  content
# ..                                                ...        ...      ...
# 95  Pitch: Novidades Jogos em promoção (mais de 4 ...  published  content
# 96  Flappy Bird, icônico jogo mobile de 2014, será...  published  content
# 97                            Não consigo comentar!!!  published  content
# 98  [NodeJS] validation-br atualizada com suporte ...  published  content
# 99  [tecnologia] Raio-X caseiro (Gerador de alta t...  published  content
#
#                                            source_url  \
# 0                                                None
# 1                                                None
# 2                          https://www.n2code.com.br/
# 3          https://github.com/mateushsx/algorithms-js
# 4                                                None
# ..                                                ...
# 95                                               None
# 96  https://www.theverge.com/2024/9/12/24242791/fl...
# 97                                               None
# 98  https://github.com/user-attachments/files/1585...
# 99        https://www.youtube.com/watch?v=h-j5BDlycwg
#
#                   created_at                updated_at  \
# 0   2024-09-18T17:16:41.657Z  2024-09-18T17:16:41.657Z
# 1   2024-09-18T16:57:46.643Z  2024-09-18T16:57:46.643Z
# 2   2024-09-18T16:51:57.689Z  2024-09-18T16:51:57.689Z
# 3   2024-09-18T16:12:54.429Z  2024-09-18T16:12:54.429Z
# 4   2024-09-18T16:05:35.445Z  2024-09-18T16:05:35.445Z
# ..                       ...                       ...
# 95  2024-09-13T16:44:58.188Z  2024-09-13T16:44:58.188Z
# 96  2024-09-13T16:41:35.708Z  2024-09-13T16:41:35.708Z
# 97  2024-09-13T15:57:04.074Z  2024-09-13T16:00:42.989Z
# 98  2024-09-13T14:56:17.491Z  2024-09-13T14:56:17.491Z
# 99  2024-09-13T14:56:14.170Z  2024-09-13T14:56:14.170Z
#
#                 published_at deleted_at      owner_username  tabcoins  \
# 0   2024-09-18T17:16:41.662Z       None             kimitri         1
# 1   2024-09-18T16:57:46.692Z       None             iamageo         1
# 2   2024-09-18T16:51:57.701Z       None  GustavoPiresN2Code         1
# 3   2024-09-18T16:12:54.470Z       None             matdevz         1
# 4   2024-09-18T16:05:35.450Z       None             iamageo         1
# ..                       ...        ...                 ...       ...
# 95  2024-09-13T16:44:58.204Z       None             saraiva         4
# 96  2024-09-13T16:41:35.713Z       None   NewsletterOficial         1
# 97  2024-09-13T15:57:04.079Z       None           Megatomix        -3
# 98  2024-09-13T14:56:17.495Z       None             klawdyo         4
# 99  2024-09-13T14:56:14.173Z       None        Wellington79         1
#
#     tabcoins_credit  tabcoins_debit  children_deep_count
# 0                 0               0                    0
# 1                 0               0                    0
# 2                 0               0                    0
# 3                 0               0                    0
# 4                 0               0                    0
# ..              ...             ...                  ...
# 95                3               0                    5
# 96                0               0                    0
# 97                2              -5                    4
# 98                3               0                    0
# 99                0               0                    0
#
# [100 rows x 17 columns]
